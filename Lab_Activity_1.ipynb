# %% [markdown]
# <a href="https://colab.research.google.com/github/otorregrosa/OOP-Lab-58001/blob/main/Lab_Activity_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Lab Activity 1 Flowchart.png](data:image/png;base64,...)

# %%
n = 20
total_number = n
sum = 0
average = 0
while (n >= 0):
  #print(n)
  sum +=n
  n-=1
print("sum =", sum)
average = sum/total_number
print("Average =", average)
# Out:
# sum = 210
# Average = 10.5
